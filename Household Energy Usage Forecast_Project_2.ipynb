# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# load data in csv file using pandas 

data=pd.read_csv('household_power_consumption.csv')
data
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_8852\2173008459.py:3: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('household_power_consumption.csv')
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# ...

# %%
#check the shape how many columns and rows in dataset 

data.shape
# Out:
# (2075259, 9)

# %%
#check the information in dataset 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
#  6   Sub_metering_1         object
#  7   Sub_metering_2         object
#  8   Sub_metering_3         float64
# dtypes: float64(1), object(8)
# memory usage: 142.5+ MB

# %%
#check the Null in dataset 

data.isnull().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power          0
# Global_reactive_power        0
# Voltage                      0
# Global_intensity             0
# Sub_metering_1               0
# Sub_metering_2               0
# Sub_metering_3           25979
# dtype: int64

# %%
#first 10 rows 

data.head(10)
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
# 5  16/12/2006  17:29:00               3.520                 0.522  235.020
# 6  16/12/2006  17:30:00               3.702                 0.520  235.090
# 7  16/12/2006  17:31:00               3.700                 0.520  235.220
# 8  16/12/2006  17:32:00               3.668                 0.510  233.990
# 9  16/12/2006  17:33:00               3.662                 0.510  233.860
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# ...

# %%
#last 10 rows 

data.tail(10)
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 2075249  26/11/2010  20:53:00               0.944                   0.0
# 2075250  26/11/2010  20:54:00               0.946                   0.0
# 2075251  26/11/2010  20:55:00               0.946                   0.0
# 2075252  26/11/2010  20:56:00               0.942                   0.0
# 2075253  26/11/2010  20:57:00               0.946                   0.0
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#         Voltage Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 2075249  238.72              4.0            0.0            0.0             0.0
# ...

# %%
#check the unique for Sub_metering_3 feature columns

data['Sub_metering_3'].unique()
# Out:
# array([17., 16., 18.,  9.,  0.,  5., 19., 10., 20.,  8.,  4.,  2.,  3.,
#        11., 13.,  6., 15., nan, 12.,  1., 14.,  7., 23., 25., 26., 28.,
#        27., 21., 22., 29., 24., 30., 31.])

# %%
#using for loop data type change for columns 

a=['Global_active_power','Global_reactive_power','Voltage','Global_intensity','Sub_metering_1','Sub_metering_2','Sub_metering_3']
for i in a:
    data[i] = pd.to_numeric(data[i], errors='coerce')

# %%
#data type change after check the information data 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    float64
#  3   Global_reactive_power  float64
#  4   Voltage                float64
#  5   Global_intensity       float64
#  6   Sub_metering_1         float64
#  7   Sub_metering_2         float64
#  8   Sub_metering_3         float64
# dtypes: float64(7), object(2)
# memory usage: 142.5+ MB

# %%
#data type change for Date Column

data['Date'] = pd.to_datetime(data['Date'],dayfirst=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   datetime64[ns]
#  1   Time                   object
#  2   Global_active_power    float64
#  3   Global_reactive_power  float64
#  4   Voltage                float64
#  5   Global_intensity       float64
#  6   Sub_metering_1         float64
#  7   Sub_metering_2         float64
#  8   Sub_metering_3         float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 142.5+ MB

# %%
#defult first 5 rows 

data.head()
# Out:
#         Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0 2006-12-16  17:24:00                4.216                  0.418   234.84
# 1 2006-12-16  17:25:00                5.360                  0.436   233.63
# 2 2006-12-16  17:26:00                5.374                  0.498   233.29
# 3 2006-12-16  17:27:00                5.388                  0.502   233.74
# 4 2006-12-16  17:28:00                3.666                  0.528   235.68
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0
# 1              23.0             0.0             1.0            16.0
# 2              23.0             0.0             2.0            17.0
# 3              23.0             0.0             1.0            17.0
# 4              15.8             0.0             1.0            17.0

# %%
# Convert Time column to a datetime object
data['Time'] = pd.to_datetime(data['Time'], format='%H:%M:%S', errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 15 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   datetime64[ns]
#  1   Time                   datetime64[ns]
#  2   Global_active_power    float64
#  3   Global_reactive_power  float64
#  4   Voltage                float64
#  5   Global_intensity       float64
#  6   Sub_metering_1         float64
#  7   Sub_metering_2         float64
#  8   Sub_metering_3         float64
#  9   Year                   int32
#  10  Month                  int32
#  11  Day                    int32
#  12  DateTime               datetime64[ns]
#  13  Hour                   int32
#  14  Minute                 int32
# dtypes: datetime64[ns](3), float64(7), int32(5)
# memory usage: 197.9 MB

# %%
#fill the Null value using mean()

data['Sub_metering_3'].fillna(data['Sub_metering_3'].mean(),inplace=True)
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_8852\3510325438.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Sub_metering_3'].fillna(data['Sub_metering_3'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3               0
# dtype: int64

# %%
#using for loop for fill the Null value in dataset

b=['Global_active_power','Global_reactive_power','Voltage',	'Global_intensity',	'Sub_metering_1','Sub_metering_2']
for i in b:
    data[i].fillna(data[i].mean(),inplace=True)
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_8852\1855354081.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[i].fillna(data[i].mean(),inplace=True)

# %%
#afer check null value 

data.isnull().sum()
# Out:
# Date                     0
# Time                     0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
#round of float data type columns 

data=data.round(2)

# %%
#check the duplicates value in dataset 

data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#               Date      Time  Global_active_power  Global_reactive_power  \
# 0       2006-12-16  17:24:00                 4.22                   0.42
# 1       2006-12-16  17:25:00                 5.36                   0.44
# 2       2006-12-16  17:26:00                 5.37                   0.50
# 3       2006-12-16  17:27:00                 5.39                   0.50
# 4       2006-12-16  17:28:00                 3.67                   0.53
# ...            ...       ...                  ...                    ...
# 2075254 2010-11-26  20:58:00                 0.95                   0.00
# 2075255 2010-11-26  20:59:00                 0.94                   0.00
# 2075256 2010-11-26  21:00:00                 0.94                   0.00
# 2075257 2010-11-26  21:01:00                 0.93                   0.00
# 2075258 2010-11-26  21:02:00                 0.93                   0.00
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
#Exract the Year,Month and Day

data['Year']=data['Date'].dt.year
data['Month']=data['Date'].dt.month
data['Day']=data['Date'].dt.day

# %%
#Extract the Hour and Minute

data['Hour']=data['Time'].dt.hour
data['Minute']=data['Time'].dt.minute

# %%
data1=data.drop(['Date','Time','DateTime'],axis=1)

# %%
data1.head()
# Out:
#    Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 0                 4.22                   0.42   234.84              18.4
# 1                 5.36                   0.44   233.63              23.0
# 2                 5.37                   0.50   233.29              23.0
# 3                 5.39                   0.50   233.74              23.0
# 4                 3.67                   0.53   235.68              15.8
#
#    Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  Month  Day  Hour  \
# 0             0.0             1.0            17.0  2006     12   16    17
# 1             0.0             1.0            16.0  2006     12   16    17
# 2             0.0             2.0            17.0  2006     12   16    17
# 3             0.0             1.0            17.0  2006     12   16    17
# 4             0.0             1.0            17.0  2006     12   16    17
#
#    Minute
# 0      24
# 1      25
# 2      26
# 3      27
# 4      28

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Global_active_power    float64
#  1   Global_reactive_power  float64
#  2   Voltage                float64
#  3   Global_intensity       float64
#  4   Sub_metering_1         float64
#  5   Sub_metering_2         float64
#  6   Sub_metering_3         float64
#  7   Year                   int32
#  8   Month                  int32
#  9   Day                    int32
#  10  Hour                   int32
#  11  Minute                 int32
# dtypes: float64(7), int32(5)
# memory usage: 150.4 MB

# %%
data1.to_csv('Household Energy_Project_2.csv',index=False)

# %%
datas=pd.read_csv('Household Energy_Project_2.csv')
datas.head()
# Out:
#    Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 0                 4.22                   0.42   234.84              18.4
# 1                 5.36                   0.44   233.63              23.0
# 2                 5.37                   0.50   233.29              23.0
# 3                 5.39                   0.50   233.74              23.0
# 4                 3.67                   0.53   235.68              15.8
#
#    Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  Month  Day  Hour  \
# 0             0.0             1.0            17.0  2006     12   16    17
# 1             0.0             1.0            16.0  2006     12   16    17
# 2             0.0             2.0            17.0  2006     12   16    17
# 3             0.0             1.0            17.0  2006     12   16    17
# 4             0.0             1.0            17.0  2006     12   16    17
#
#    Minute
# 0      24
# 1      25
# 2      26
# 3      27
# 4      28

# %%
#Analysis for Numerical columns using Describe 

datas.describe()
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         2.075259e+06           2.075259e+06  2.075259e+06
# mean          1.091601e+00           1.237028e-01  2.408399e+02
# std           1.050656e+00           1.120170e-01  3.219643e+00
# min           8.000000e-02           0.000000e+00  2.232000e+02
# 25%           3.100000e-01           5.000000e-02  2.390200e+02
# 50%           6.300000e-01           1.000000e-01  2.409600e+02
# 75%           1.520000e+00           1.900000e-01  2.428600e+02
# max           1.112000e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# count      2.075259e+06    2.075259e+06    2.075259e+06    2.075259e+06
# mean       4.627787e+00    1.121899e+00    1.298538e+00    6.458467e+00
# std        4.416490e+00    6.114397e+00    5.785470e+00    8.384178e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# ...

# %%
# Create rolling averages for smoothing

datas['Rolling_Avg_Power'] = datas['Global_active_power'].rolling(window=10).mean()

# %%
#check the unique values in Rolling Average columns 

datas['Rolling_Avg_Power'].unique()
# Out:
# array([  nan, 4.226, 4.249, ..., 6.264, 6.135, 5.107])

# %%
#missing value apply mean value

datas['Rolling_Avg_Power'].fillna(datas['Rolling_Avg_Power'].mean(),inplace=True)
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\2330287638.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   datas['Rolling_Avg_Power'].fillna(datas['Rolling_Avg_Power'].mean(),inplace=True)

# %%
#Missing values 
datas.isnull().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# Year                     0
# Month                    0
# Day                      0
# Hour                     0
# Minute                   0
# Rolling_Avg_Power        0
# dtype: int64

# %%
#round of data floating points 2 decimal 

house=datas.round(2)

# %%
house.head()
# Out:
#    Global_active_power  Global_reactive_power  Voltage  Global_intensity  \
# 0                 4.22                   0.42   234.84              18.4
# 1                 5.36                   0.44   233.63              23.0
# 2                 5.37                   0.50   233.29              23.0
# 3                 5.39                   0.50   233.74              23.0
# 4                 3.67                   0.53   235.68              15.8
#
#    Sub_metering_1  Sub_metering_2  Sub_metering_3  Year  Month  Day  Hour  \
# 0             0.0             1.0            17.0  2006     12   16    17
# 1             0.0             1.0            16.0  2006     12   16    17
# 2             0.0             2.0            17.0  2006     12   16    17
# 3             0.0             1.0            17.0  2006     12   16    17
# 4             0.0             1.0            17.0  2006     12   16    17
#
#    Minute  Rolling_Avg_Power
# 0      24               1.09
# ...

# %%
#Identifiy outliers using Box plot 

plt.figure(figsize=(25,10))
sns.boxplot(data=house,width=0.5)
plt.show()

# %%
#Identify outliers using Boxplot colunm 'Global_active_power'

plt.figure(figsize=(20,8))
sns.boxplot(house['Global_active_power'])
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Global_active_power'

sns.distplot(house['Global_active_power'])
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\3454337113.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Global_active_power'])
# <Axes: xlabel='Global_active_power', ylabel='Density'>

# %%
#Identify outliers using Boxplot colunm 'Global_reactive_power'

plt.figure(figsize=(20,8))
sns.boxplot(house['Global_reactive_power'])
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Global_reactive_power'

plt.figure(figsize=(20,8))
sns.distplot(house['Global_reactive_power'])
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\69110904.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Global_reactive_power'])

# %%
#Identify outliers using Boxplot colunm 'Voltage'

plt.figure(figsize=(20,8))
sns.boxplot(house['Voltage'])
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Voltage'

plt.figure(figsize=(20,8))
sns.distplot(house['Voltage'])
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\2536511662.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Voltage'])

# %%
#Identify outliers using Boxplot colunm 'Global_intensity'

plt.figure(figsize=(20,8))
sns.boxplot(house['Global_intensity'])
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Global_intensity'

plt.figure(figsize=(20,8))
sns.distplot(house['Global_intensity'])
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\826071327.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Global_intensity'])

# %%
#Identify outliers using Boxplot colunm 'Sub_metering_1'

plt.figure(figsize=(20,8))
sns.boxplot(house['Sub_metering_1'],width=0.3)
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Sub_metering_1'

plt.figure(figsize=(20,8))
sns.distplot(house['Sub_metering_1'])
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\949633479.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Sub_metering_1'])

# %%
house['Sub_metering_1'].unique()
# Out:
# array([ 0.  ,  1.  ,  2.  ,  6.  , 37.  , 36.  , 38.  , 25.  , 12.  ,
#        11.  ,  9.  ,  4.  , 33.  ,  5.  , 34.  ,  8.  , 26.  , 27.  ,
#        15.  , 20.  , 21.  , 23.  , 16.  , 10.  , 39.  , 32.  ,  1.12,
#        19.  , 35.  , 30.  , 40.  ,  7.  , 31.  , 17.  ,  3.  , 29.  ,
#        24.  , 14.  , 41.  , 53.  , 76.  , 75.  , 77.  , 74.  , 28.  ,
#        68.  , 58.  , 62.  , 13.  , 18.  , 22.  , 64.  , 71.  , 56.  ,
#        72.  , 45.  , 42.  , 59.  , 66.  , 43.  , 44.  , 48.  , 46.  ,
#        73.  , 55.  , 60.  , 70.  , 63.  , 67.  , 47.  , 65.  , 51.  ,
#        50.  , 69.  , 78.  , 57.  , 49.  , 61.  , 52.  , 54.  , 79.  ,
#        80.  , 81.  , 82.  , 83.  , 84.  , 88.  , 86.  , 87.  ])

# %%
#Identify outliers using Boxplot colunm 'Sub_metering_2'

plt.figure(figsize=(20,8))
plt.boxplot(house['Sub_metering_2'])
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Sub_metering_2'

plt.figure(figsize=(20,8))
sns.distplot(house['Sub_metering_2'])
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\2252179412.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Sub_metering_2'])

# %%
#Identify outliers using Boxplot colunm 'Sub_metering_3'

plt.figure(figsize=(20,8))
sns.boxplot(house['Sub_metering_3'],width=0.3)
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Sub_metering_1'

plt.figure(figsize=(20,8))
sns.distplot(house['Sub_metering_3'])
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\2390959453.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Sub_metering_3'])

# %%
#Identify outliers using Boxplot colunm 'Year'

plt.figure(figsize=(20,8))
plt.boxplot(house['Year'])
plt.title('Outliers',fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.boxplot(house['Month'],width=0.3)
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Month'

plt.figure(figsize=(20,8))
sns.distplot(house['Month'])
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\3688751566.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Month'])

# %%
#Identify outliers using Boxplot colunm 'Day'

plt.figure(figsize=(20,8))
sns.boxplot(house['Day'],width=0.3)
plt.title('Outliers',fontsize=30)plt.show()
plt.show()
# Out:
#   Cell In[139], line 5
#     plt.title('Outliers',fontsize=30)plt.show()
#                                      ^
# SyntaxError: invalid syntax

# %%
#Identifying Skewness using distplot column 'Day'

plt.figure(figsize=(20,8))
sns.distplot(house['Day'])
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\1254803741.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Day'])

# %%
#Identify outliers using Boxplot colunm 'Rolling_Avg_Power'

plt.figure(figsize=(20,8))
sns.boxplot(house['Rolling_Avg_Power'],width=0.3)
plt.title('Outliers',fontsize=30)
plt.show()

# %%
#Identifying Skewness using distplot column 'Rolling_Avg_Power'

plt.figure(figsize=(20,8))
sns.distplot(house['Rolling_Avg_Power'])
plt.title('Distribution Plot')
plt.show()
# Out:
# C:\Users\vnave\AppData\Local\Temp\ipykernel_108\1753069047.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['Rolling_Avg_Power'])

# %%
#Identify the Correlation using Heatmap

plt.figure(figsize=(20,8))
sns.heatmap(house.corr(),annot=True,fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap",fontsize=30)
plt.show()
